# %%
import pandas as pd

df = pd.read_csv("general_data.csv")

df[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', \
    'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',\
    'YearsSinceLastPromotion', 'YearsWithCurrManager']]\
.describe()
# Out:
#                Age  DistanceFromHome    Education  MonthlyIncome  \
# count  4410.000000       4410.000000  4410.000000    4410.000000
# mean     36.923810          9.192517     2.912925   65029.312925
# std       9.133301          8.105026     1.023933   47068.888559
# min      18.000000          1.000000     1.000000   10090.000000
# 25%      30.000000          2.000000     2.000000   29110.000000
# 50%      36.000000          7.000000     3.000000   49190.000000
# 75%      43.000000         14.000000     4.000000   83800.000000
# max      60.000000         29.000000     5.000000  199990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count         4391.000000        4410.000000        4401.000000
# mean             2.694830          15.209524          11.279936
# std              2.498887           3.659108           7.782222
# min              0.000000          11.000000           0.000000
# ...

# %%
df_a = df[df['Attrition']=='Yes']

# %%
df_a[['Age','DistanceFromHome','MonthlyIncome','Education','NumCompaniesWorked', \
      'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',\
      'YearsSinceLastPromotion', 'YearsWithCurrManager']].\
describe()
# Out:
#               Age  DistanceFromHome  MonthlyIncome   Education  \
# count  711.000000        711.000000     711.000000  711.000000
# mean    33.607595          9.012658   61682.616034    2.877637
# std      9.675693          7.772368   44792.067695    1.014233
# min     18.000000          1.000000   10090.000000    1.000000
# 25%     28.000000          2.000000   28440.000000    2.000000
# 50%     32.000000          7.000000   49080.000000    3.000000
# 75%     39.000000         15.000000   71040.000000    4.000000
# max     58.000000         29.000000  198590.000000    5.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count          707.000000         711.000000         709.000000
# mean             2.936351          15.481013           8.255289
# std              2.678774           3.775289           7.164018
# min              0.000000          11.000000           0.000000
# 25%              1.000000          12.000000           3.000000
# ...

# %%
df_a[df_a['Gender']=='Male'].describe()
# Out:
#               Age  DistanceFromHome   Education  EmployeeCount   EmployeeID  \
# count  441.000000        441.000000  441.000000          441.0   441.000000
# mean    33.312925          8.170068    2.931973            1.0  2202.108844
# std      9.675980          7.170369    0.967611            0.0  1267.130253
# min     18.000000          1.000000    1.000000            1.0     7.000000
# 25%     27.000000          2.000000    2.000000            1.0  1041.000000
# 50%     32.000000          7.000000    3.000000            1.0  2188.000000
# 75%     39.000000         12.000000    4.000000            1.0  3371.000000
# max     58.000000         28.000000    5.000000            1.0  4403.000000
#
#          JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  441.000000     441.000000          438.000000         441.000000
# mean     1.993197   61830.680272            2.819635          15.387755
# ...

# %%
df_a[df_a['Gender']=='Female'].describe()
# Out:
#               Age  DistanceFromHome   Education  EmployeeCount   EmployeeID  \
# count  270.000000        270.000000  270.000000          270.0   270.000000
# mean    34.088889         10.388889    2.788889            1.0  2174.877778
# std      9.673838          8.501950    1.082072            0.0  1277.207801
# min     20.000000          1.000000    1.000000            1.0     2.000000
# 25%     28.000000          3.000000    2.000000            1.0  1085.500000
# 50%     31.500000          7.500000    3.000000            1.0  2134.500000
# 75%     40.000000         16.000000    4.000000            1.0  3280.250000
# max     58.000000         29.000000    5.000000            1.0  4382.000000
#
#          JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  270.000000     270.000000          269.000000         270.000000
# mean     2.111111   61440.777778            3.126394          15.633333
# ...

# %%
df_g = df_a.groupby('Department')

df_g.count()
# Out:
#                         Age  Attrition  BusinessTravel  DistanceFromHome  \
# Department
# Human Resources          57         57              57                57
# Research & Development  453        453             453               453
# Sales                   201        201             201               201
#
#                         Education  EducationField  EmployeeCount  EmployeeID  \
# Department
# Human Resources                57              57             57          57
# Research & Development        453             453            453         453
# Sales                         201             201            201         201
#
#                         Gender  JobLevel  ...  NumCompaniesWorked  Over18  \
# Department                                ...
# Human Resources             57        57  ...                  56      57
# Research & Development     453       453  ...                 450     453
# ...

# %% [markdown]
# Statement 1: Employees of age 34 or lesser usually leave the company for better opportunities.

# %% [markdown]
# Statement 2: Attrition rate of female employees is lesser than that of male employees.

# %% [markdown]
# Statement 3: Research & Development department might have higher work pressure compared to other departments.

# %% [markdown]
# Statement 4: Most employees who have left the organization have served the company for over 5 years.

# %% [markdown]
# Statement 5: The average monthly income of the employees who have left the oraganisation is lesser than the total average salary of all the employees.

# %% [markdown]
# Statement 6 : Male Employees tend to live little closer to the organization compared to female employees, considering the average distance from home.
